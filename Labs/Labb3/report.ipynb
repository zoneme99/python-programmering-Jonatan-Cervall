# %%
import Labb3


Labb3.run(-1, 0)
print(left)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 import Labb3
#       4 Labb3.run(-1, 0)
# ----> 5 print(left)
#
# NameError: name 'left' is not defined
